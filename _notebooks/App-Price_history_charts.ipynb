# %% [markdown]
# # Kainų istorija
# > Normalizuota kainų istorija BTC, ETH ir ICO
#
# - toc: true
# - badges: true
# - comments: false
# - categories: [jupyter]
# - image: images/BTC_price.png

# %%
#hide
import plotly.graph_objects as go
import pandas as pd
from scripts.read_data import read
from IPython.display import HTML

# %%
#hide
df_all = read()
df_norm = (df_all - df_all.mean()) / (df_all.max() - df_all.min())
# Out:
# D:\Users\SmOgER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\frame.py:7134: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#hide_input
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.ADA),
               name="ADA",
               line=dict(color="DarkOrange")))

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.EOS),
               name="EOS",
               line=dict(color="Crimson")))


fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.IOTA),
               name="IOTA",
               line=dict(color="RebeccaPurple")))

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.LSK),
               name="LSK",
               line=dict(color="Purple")))

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.NEO),
               name="NEO",
               line=dict(color="Red")))

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.TRX),
               name="TRX",
               line=dict(color="Green")))

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.ETH),
               name="ETH",
               line=dict(color="Yellow")))

fig.add_trace(
    go.Scatter(x=list(df_norm.index),
               y=list(df_norm.BTC),
               name="BTC",
               line=dict(color="Black")))


fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="right",
            active=0,
            x=1.57,
            y=1.2,
            buttons=list([
                dict(label="ADA",
                     method="update",
                     args=[{"visible": [True, False, False, False, False, False, False, False]},
                           {"title": "ADA",
                            "annotations": []}]),
                dict(label="EOD",
                     method="update",
                     args=[{"visible": [False, True, False, False, False, False, False, False]},
                           {"title": "EOD",
                            "annotations": []}]),
                dict(label="IOTA",
                     method="update",
                     args=[{"visible": [False, False, True, False, False, False, False, False]},
                           {"title": "IOTA",
                            "annotations": [] }]),
                 dict(label="LSK",
                     method="update",
                     args=[{"visible": [False, False, False, True, False, False, False, False]},
                           {"title": "LSK",
                            "annotations": [] }]),
                 dict(label="NEO",
                     method="update",
                     args=[{"visible": [False, False, False, False, True, False, False, False]},
                           {"title": "NEO",
                            "annotations": [] }]),
                 dict(label="TRX",
                     method="update",
                     args=[{"visible": [False, False, False, False, False, True, False, False]},
                           {"title": "TRX",
                            "annotations": [] }]),
                dict(label="ETH",
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, True, False]},
                           {"title": "ETH",
                            "annotations": [] }]),
                dict(label="BTC",
                     method="update",
